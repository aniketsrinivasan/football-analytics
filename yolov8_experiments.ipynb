# %% [markdown]
# # Experimenting with YOLOv5 and YOLOv8 (Ultralytics)
# We'd like to experiment with the package and see its pre-trained capabilities before fine-tuning for our task.

# %% [markdown]
# ### Initial Experimentation with Base-Model Networks

# %%
# Path to main directory:
ROOT_DIR = "/Users/aniket/PycharmProjects/footballAnalytics"

from ultralytics import YOLO
# Importing YOLOv8x (the medium-size YOLOv8 engine)
model = YOLO("yolov8m")

# Saving a sample prediction:
#   sample_predicts is a list of frame-wise predictions, so each frame is an element
sample_predicts = model.predict(ROOT_DIR + "/football_data/sample_data/0a2d9b_5.mp4", save=False)

# Printing the first element (frame) of sample_predicts:
print(sample_predicts[0])
print("===============================")      # Line separator

# Printing the bounding boxes of the first element (frame) of sample_predicts:
for box in sample_predicts[0].boxes:
    print(box)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 22 persons, 1 tv, 199.8ms
# video 1/1 (frame 2/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 18 persons, 1 tv, 189.3ms
# video 1/1 (frame 3/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 19 persons, 1 tv, 181.8ms
# video 1/1 (frame 4/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 18 persons, 1 tv, 204.6ms
# video 1/1 (frame 5/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 21 persons, 1 tv, 200.2ms
# video 1/1 (frame 6/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 21 persons, 1 tv, 198.5ms
# video 1/1 (frame 7/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 21 persons, 1 tv, 183.7ms
# video 1/1 (frame 8/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 20 persons, 1 tv, 193.6ms
# video 1/1 (frame 9/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 19 persons, 1 tv, 240.2ms
# video 1/1 (frame 10/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 20 persons, 1 tv, 185.1ms
# video 1/1 (frame 11/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 20 persons, 1 tv, 192.3ms
# video 1/1 (frame 12/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 20 persons, 1 tv, 191.6ms
# video 1/1 (frame 13/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 20 persons, 1 tv, 203.4ms
# video 1/1 (frame 14/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 20 persons, 1 tv, 196.8ms
# video 1/1 (frame 15/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 20 persons, 1 tv, 184.6ms
# video 1/1 (frame 16/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 20 persons, 1 tv, 187.7ms
# video 1/1 (frame 17/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 20 persons, 1 tv, 183.2ms
# video 1/1 (frame 18/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 20 persons, 1 tv, 188.1ms
# video 1/1 (frame 19/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 21 persons, 1 tv, 186.8ms
# video 1/1 (frame 20/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 20 persons, 1 tv, 181.0ms
# video 1/1 (frame 21/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 21 persons, 1 tv, 191.2ms
# video 1/1 (frame 22/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 20 persons, 1 tennis racket, 1 tv, 201.2ms
# video 1/1 (frame 23/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 20 persons, 1 tv, 190.2ms
# video 1/1 (frame 24/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 21 persons, 1 tv, 189.4ms
# video 1/1 (frame 25/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 22 persons, 1 tv, 190.9ms
# video 1/1 (frame 26/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 22 persons, 1 tv, 199.0ms
# video 1/1 (frame 27/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 22 persons, 1 tv, 187.0ms
# video 1/1 (frame 28/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 22 persons, 1 tv, 175.4ms
# video 1/1 (frame 29/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 22 persons, 1 tv, 183.6ms
# video 1/1 (frame 30/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 22 persons, 1 tv, 185.2ms
# video 1/1 (frame 31/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 22 persons, 1 tv, 191.2ms
# video 1/1 (frame 32/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 22 persons, 1 tv, 210.1ms
# video 1/1 (frame 33/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 21 persons, 189.5ms
# video 1/1 (frame 34/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 20 persons, 198.1ms
# video 1/1 (frame 35/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 21 persons, 192.7ms
# video 1/1 (frame 36/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 20 persons, 1 tv, 189.5ms
# video 1/1 (frame 37/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 22 persons, 1 tv, 196.4ms
# video 1/1 (frame 38/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 21 persons, 1 tv, 191.9ms
# video 1/1 (frame 39/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 384x640 21 persons, 1 tv, 194.5ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 10
#       6 model = YOLO("yolov8m")
#       8 # Saving a sample prediction:
#       9 #   sample_predicts is a list of frame-wise predictions, so each frame is an element
# ---> 10 sample_predicts = model.predict(ROOT_DIR + "/football_data/sample_data/0a2d9b_5.mp4", save=False)
#      12 # Printing the first element (frame) of sample_predicts:
#      13 print(sample_predicts[0])
#
# File ~/anaconda3/lib/python3.11/site-packages/ultralytics/engine/model.py:452, in Model.predict(self, source, stream, predictor, **kwargs)
#     450 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     451     self.predictor.set_prompts(prompts)
# --> 452 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/anaconda3/lib/python3.11/site-packages/ultralytics/engine/predictor.py:168, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     166     return self.stream_inference(source, model, *args, **kwargs)
#     167 else:
# --> 168     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/utils/_contextlib.py:56, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      53         else:
#      54             # Pass the last request to the generator and get its response
#      55             with ctx_factory():
# ---> 56                 response = gen.send(request)
#      58 # We let the exceptions raised above by the generator's `.throw` or
#      59 # `.send` methods bubble up to our caller, except for StopIteration
#      60 except StopIteration as e:
#      61     # The generator informed us that it is done: take whatever its
#      62     # returned value (if any) was and indicate that we're done too
#      63     # by returning it (see docs for python's return-statement).
#
# File ~/anaconda3/lib/python3.11/site-packages/ultralytics/engine/predictor.py:248, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     246 # Inference
#     247 with profilers[1]:
# --> 248     preds = self.inference(im, *args, **kwargs)
#     249     if self.args.embed:
#     250         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~/anaconda3/lib/python3.11/site-packages/ultralytics/engine/predictor.py:142, in BasePredictor.inference(self, im, *args, **kwargs)
#     136 """Runs inference on a given image using the specified model and arguments."""
#     137 visualize = (
#     138     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     139     if self.args.visualize and (not self.source_type.tensor)
#     140     else False
#     141 )
# --> 142 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/anaconda3/lib/python3.11/site-packages/ultralytics/nn/autobackend.py:453, in AutoBackend.forward(self, im, augment, visualize, embed)
#     451 # PyTorch
#     452 if self.pt or self.nn_module:
# --> 453     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     455 # TorchScript
#     456 elif self.jit:
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/anaconda3/lib/python3.11/site-packages/ultralytics/nn/tasks.py:89, in BaseModel.forward(self, x, *args, **kwargs)
#      87 if isinstance(x, dict):  # for cases of training and validating while training.
#      88     return self.loss(x, *args, **kwargs)
# ---> 89 return self.predict(x, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/ultralytics/nn/tasks.py:107, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     105 if augment:
#     106     return self._predict_augment(x)
# --> 107 return self._predict_once(x, profile, visualize, embed)
#
# File ~/anaconda3/lib/python3.11/site-packages/ultralytics/nn/tasks.py:128, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     126 if profile:
#     127     self._profile_one_layer(m, x, dt)
# --> 128 x = m(x)  # run
#     129 y.append(x if m.i in self.save else None)  # save output
#     130 if visualize:
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/anaconda3/lib/python3.11/site-packages/ultralytics/nn/modules/block.py:230, in C2f.forward(self, x)
#     228 """Forward pass through C2f layer."""
#     229 y = list(self.cv1(x).chunk(2, 1))
# --> 230 y.extend(m(y[-1]) for m in self.m)
#     231 return self.cv2(torch.cat(y, 1))
#
# File ~/anaconda3/lib/python3.11/site-packages/ultralytics/nn/modules/block.py:230, in <genexpr>(.0)
#     228 """Forward pass through C2f layer."""
#     229 y = list(self.cv1(x).chunk(2, 1))
# --> 230 y.extend(m(y[-1]) for m in self.m)
#     231 return self.cv2(torch.cat(y, 1))
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/anaconda3/lib/python3.11/site-packages/ultralytics/nn/modules/block.py:340, in Bottleneck.forward(self, x)
#     338 def forward(self, x):
#     339     """'forward()' applies the YOLO FPN to input data."""
# --> 340     return x + self.cv2(self.cv1(x)) if self.add else self.cv2(self.cv1(x))
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/anaconda3/lib/python3.11/site-packages/ultralytics/nn/modules/conv.py:54, in Conv.forward_fuse(self, x)
#      52 def forward_fuse(self, x):
#      53     """Perform transposed convolution of 2D data."""
# ---> 54     return self.act(self.conv(x))
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Fine-Tuning YOLOv5 for ball detection

# %%
from roboflow import Roboflow
# Downloading the football detection dataset from Roboflow:
rf = Roboflow(api_key="4RqzasAeTwRGw27fWaXx")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(8)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in football-players-detection-8 to yolov5pytorch:: 100%|████████████████| 57648/57648 [00:20<00:00, 2843.84it/s]
# Extracting Dataset Version Zip to football-players-detection-8 in yolov5pytorch:: 100%|█████████████████████| 522/522 [00:00<00:00, 2927.62it/s]

# %%
# # Training the YOLOv5 model on the dataset (fine-tuning):
# #    We are using YOLOv5-large here. Main model for YOLOv8 is YOLOv8-medium.

# # Note: run this on a Google Colab using a cloud GPU:

# !pip install ultralytics
# !pip install roboflow

# from ultralytics import YOLO
# from roboflow import Roboflow
# # Downloading the football detection dataset from Roboflow:
# rf = Roboflow(api_key="4RqzasAeTwRGw27fWaXx")
# project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
# version = project.version(8)

# dataset = version.download("yolov5")
# !yolo task=detect mode=train model=yolov5l data=(dataset.location)/data.yaml epochs=64 imgsz=768

# %% [markdown]
# #### Running fine-tuned YOLOv5 on the sample video:

# %%
# Path to main directory:
ROOT_DIR = "/Users/aniket/PycharmProjects/footballAnalytics"

from ultralytics import YOLO
# Importing YOLOv8x (the medium-size YOLOv8 engine)
model = YOLO("/Users/aniket/PycharmProjects/footballAnalytics/.ipynb_checkpoints/models/best.pt")

# Saving a sample prediction:
#   sample_predicts is a list of frame-wise predictions, so each frame is an element
sample_predicts = model.predict(ROOT_DIR + "/football_data/sample_data/0a2d9b_5.mp4", save=True)

# Printing the first element (frame) of sample_predicts:
print(sample_predicts[0])
print("===============================")      # Line separator

# Printing the bounding boxes of the first element (frame) of sample_predicts:
for box in sample_predicts[0].boxes:
    print(box)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/751) /Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4: 448x768 20 players, 2 referees,
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
# obb: None
# orig_img: array([[[ 44,  26,  35],
#         [ 46,  28,  38],
#         [ 46,  28,  38],
#         ...,
#         [ 60,  42,  49],
#         [ 62,  45,  52],
#         [ 62,  45,  52]],
#
#        [[ 44,  26,  35],
#         [ 46,  28,  38],
#         [ 46,  28,  38],
#         ...,
#         [ 60,  42,  49],
#         [ 62,  45,  52],
#         [ 62,  45,  52]],
#
#        [[ 44,  26,  35],
#         [ 45,  27,  37],
#         [ 45,  27,  37],
#         ...,
#         [ 60,  42,  49],
#         [ 62,  45,  52],
#         [ 62,  45,  52]],
#
#        ...,
#
#        [[208, 252, 251],
#         [208, 252, 251],
#         [208, 252, 251],
#         ...,
#         [ 65,  53,  80],
#         [ 65,  55,  76],
#         [ 62,  53,  74]],
#
#        [[196, 253, 252],
#         [196, 253, 252],
#         [196, 253, 252],
#         ...,
#         [ 88,  75, 100],
#         [ 83,  73,  91],
#         [ 80,  69,  88]],
#
#        [[196, 253, 252],
#         [196, 253, 252],
#         [196, 253, 252],
#         ...,
#         [101,  88, 112],
#         [ 87,  76,  95],
#         [ 79,  68,  87]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/Users/aniket/PycharmProjects/footballAnalytics/football_data/sample_data/0a2d9b_5.mp4'
# probs: None
# save_dir: 'runs/detect/predict2'
# speed: {'preprocess': 9.694814682006836, 'inference': 740.2188777923584, 'postprocess': 12.353897094726562}
# ===============================
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.9100])
# data: tensor([[430.0682, 513.6842, 470.0352, 592.5405,   0.9100,   2.0000]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[450.0517, 553.1123,  39.9670,  78.8563]])
# xywhn: tensor([[0.2344, 0.5121, 0.0208, 0.0730]])
# xyxy: tensor([[430.0682, 513.6842, 470.0352, 592.5405]])
# xyxyn: tensor([[0.2240, 0.4756, 0.2448, 0.5486]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.9045])
# data: tensor([[1.0577e+03, 6.0906e+02, 1.0883e+03, 7.0203e+02, 9.0452e-01, 2.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1073.0125,  655.5458,   30.6171,   92.9681]])
# xywhn: tensor([[0.5589, 0.6070, 0.0159, 0.0861]])
# xyxy: tensor([[1057.7040,  609.0617, 1088.3210,  702.0298]])
# xyxyn: tensor([[0.5509, 0.5639, 0.5668, 0.6500]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.8972])
# data: tensor([[1.1629e+03, 3.0979e+02, 1.1880e+03, 3.5709e+02, 8.9719e-01, 2.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1175.4668,  333.4419,   25.1293,   47.3041]])
# xywhn: tensor([[0.6122, 0.3087, 0.0131, 0.0438]])
# xyxy: tensor([[1162.9022,  309.7899, 1188.0315,  357.0940]])
# xyxyn: tensor([[0.6057, 0.2868, 0.6188, 0.3306]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.8810])
# data: tensor([[289.1797, 484.5638, 319.6999, 551.0673,   0.8810,   2.0000]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[304.4398, 517.8156,  30.5202,  66.5036]])
# xywhn: tensor([[0.1586, 0.4795, 0.0159, 0.0616]])
# xyxy: tensor([[289.1797, 484.5638, 319.6999, 551.0673]])
# xyxyn: tensor([[0.1506, 0.4487, 0.1665, 0.5102]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([3.])
# conf: tensor([0.8764])
# data: tensor([[692.1262, 404.5449, 723.6096, 468.3585,   0.8764,   3.0000]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[707.8679, 436.4517,  31.4833,  63.8136]])
# xywhn: tensor([[0.3687, 0.4041, 0.0164, 0.0591]])
# xyxy: tensor([[692.1262, 404.5449, 723.6096, 468.3585]])
# xyxyn: tensor([[0.3605, 0.3746, 0.3769, 0.4337]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.8734])
# data: tensor([[1.3037e+03, 3.4628e+02, 1.3388e+03, 4.0312e+02, 8.7335e-01, 2.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1321.2644,  374.6978,   35.1639,   56.8398]])
# xywhn: tensor([[0.6882, 0.3469, 0.0183, 0.0526]])
# xyxy: tensor([[1303.6825,  346.2779, 1338.8464,  403.1177]])
# xyxyn: tensor([[0.6790, 0.3206, 0.6973, 0.3733]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.8732])
# data: tensor([[9.3989e+02, 4.1406e+02, 9.6061e+02, 4.7772e+02, 8.7321e-01, 2.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[950.2527, 445.8883,  20.7175,  63.6624]])
# xywhn: tensor([[0.4949, 0.4129, 0.0108, 0.0589]])
# xyxy: tensor([[939.8939, 414.0571, 960.6114, 477.7195]])
# xyxyn: tensor([[0.4895, 0.3834, 0.5003, 0.4423]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.8692])
# data: tensor([[8.9338e+02, 3.7551e+02, 9.1536e+02, 4.3192e+02, 8.6918e-01, 2.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[904.3698, 403.7183,  21.9885,  56.4120]])
# xywhn: tensor([[0.4710, 0.3738, 0.0115, 0.0522]])
# xyxy: tensor([[893.3755, 375.5124, 915.3641, 431.9243]])
# xyxyn: tensor([[0.4653, 0.3477, 0.4768, 0.3999]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.8680])
# data: tensor([[811.5793, 310.8704, 831.5199, 356.1272,   0.8680,   2.0000]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[821.5496, 333.4988,  19.9406,  45.2568]])
# xywhn: tensor([[0.4279, 0.3088, 0.0104, 0.0419]])
# xyxy: tensor([[811.5793, 310.8704, 831.5199, 356.1272]])
# xyxyn: tensor([[0.4227, 0.2878, 0.4331, 0.3297]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.8677])
# data: tensor([[334.1251, 404.5912, 356.2162, 463.8383,   0.8677,   2.0000]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[345.1707, 434.2147,  22.0911,  59.2470]])
# xywhn: tensor([[0.1798, 0.4021, 0.0115, 0.0549]])
# xyxy: tensor([[334.1251, 404.5912, 356.2162, 463.8383]])
# xyxyn: tensor([[0.1740, 0.3746, 0.1855, 0.4295]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.8664])
# data: tensor([[650.8914, 352.0513, 671.4769, 403.3310,   0.8664,   2.0000]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[661.1841, 377.6912,  20.5854,  51.2797]])
# xywhn: tensor([[0.3444, 0.3497, 0.0107, 0.0475]])
# xyxy: tensor([[650.8914, 352.0513, 671.4769, 403.3310]])
# xyxyn: tensor([[0.3390, 0.3260, 0.3497, 0.3735]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.8656])
# data: tensor([[753.5307, 383.4055, 771.3325, 442.2432,   0.8656,   2.0000]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[762.4316, 412.8243,  17.8018,  58.8377]])
# xywhn: tensor([[0.3971, 0.3822, 0.0093, 0.0545]])
# xyxy: tensor([[753.5307, 383.4055, 771.3325, 442.2432]])
# xyxyn: tensor([[0.3925, 0.3550, 0.4017, 0.4095]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.8644])
# data: tensor([[574.1871, 343.3153, 593.1282, 396.3250,   0.8644,   2.0000]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[583.6577, 369.8201,  18.9410,  53.0096]])
# xywhn: tensor([[0.3040, 0.3424, 0.0099, 0.0491]])
# xyxy: tensor([[574.1871, 343.3153, 593.1282, 396.3250]])
# xyxyn: tensor([[0.2991, 0.3179, 0.3089, 0.3670]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.8461])
# data: tensor([[308.9980, 388.5433, 335.3732, 447.9271,   0.8461,   2.0000]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[322.1856, 418.2352,  26.3753,  59.3838]])
# xywhn: tensor([[0.1678, 0.3873, 0.0137, 0.0550]])
# xyxy: tensor([[308.9980, 388.5433, 335.3732, 447.9271]])
# xyxyn: tensor([[0.1609, 0.3598, 0.1747, 0.4147]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.8379])
# data: tensor([[735.4023, 304.5413, 753.4221, 349.0723,   0.8379,   2.0000]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[744.4122, 326.8068,  18.0197,  44.5309]])
# xywhn: tensor([[0.3877, 0.3026, 0.0094, 0.0412]])
# xyxy: tensor([[735.4023, 304.5413, 753.4221, 349.0723]])
# xyxyn: tensor([[0.3830, 0.2820, 0.3924, 0.3232]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.8366])
# data: tensor([[477.4245, 310.7065, 497.3961, 356.7194,   0.8366,   2.0000]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[487.4103, 333.7129,  19.9716,  46.0129]])
# xywhn: tensor([[0.2539, 0.3090, 0.0104, 0.0426]])
# xyxy: tensor([[477.4245, 310.7065, 497.3961, 356.7194]])
# xyxyn: tensor([[0.2487, 0.2877, 0.2591, 0.3303]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.8347])
# data: tensor([[529.3369, 299.0342, 544.8028, 340.9901,   0.8347,   2.0000]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[537.0698, 320.0122,  15.4659,  41.9559]])
# xywhn: tensor([[0.2797, 0.2963, 0.0081, 0.0388]])
# xyxy: tensor([[529.3369, 299.0342, 544.8028, 340.9901]])
# xyxyn: tensor([[0.2757, 0.2769, 0.2838, 0.3157]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.8233])
# data: tensor([[9.7116e+02, 3.2161e+02, 9.9154e+02, 3.6932e+02, 8.2328e-01, 2.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[981.3494, 345.4664,  20.3865,  47.7153]])
# xywhn: tensor([[0.5111, 0.3199, 0.0106, 0.0442]])
# xyxy: tensor([[971.1561, 321.6087, 991.5426, 369.3240]])
# xyxyn: tensor([[0.5058, 0.2978, 0.5164, 0.3420]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.8193])
# data: tensor([[283.3525, 446.8905, 305.4989, 505.6145,   0.8193,   2.0000]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[294.4257, 476.2525,  22.1464,  58.7241]])
# xywhn: tensor([[0.1533, 0.4410, 0.0115, 0.0544]])
# xyxy: tensor([[283.3525, 446.8905, 305.4989, 505.6145]])
# xyxyn: tensor([[0.1476, 0.4138, 0.1591, 0.4682]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.8024])
# data: tensor([[9.9294e+02, 3.4486e+02, 1.0117e+03, 3.9599e+02, 8.0242e-01, 2.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1002.3068,  370.4221,   18.7393,   51.1278]])
# xywhn: tensor([[0.5220, 0.3430, 0.0098, 0.0473]])
# xyxy: tensor([[ 992.9371,  344.8582, 1011.6765,  395.9859]])
# xyxyn: tensor([[0.5172, 0.3193, 0.5269, 0.3667]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.7140])
# data: tensor([[8.4628e+02, 2.8128e+02, 8.6817e+02, 3.1925e+02, 7.1398e-01, 2.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[857.2242, 300.2658,  21.8875,  37.9659]])
# xywhn: tensor([[0.4465, 0.2780, 0.0114, 0.0352]])
# xyxy: tensor([[846.2805, 281.2828, 868.1680, 319.2488]])
# xyxyn: tensor([[0.4408, 0.2604, 0.4522, 0.2956]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([3.])
# conf: tensor([0.4026])
# data: tensor([[1.7061e+03, 7.9188e+02, 1.7636e+03, 9.1288e+02, 4.0263e-01, 3.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1734.8650,  852.3798,   57.5592,  120.9909]])
# xywhn: tensor([[0.9036, 0.7892, 0.0300, 0.1120]])
# xyxy: tensor([[1706.0854,  791.8843, 1763.6447,  912.8752]])
# xyxyn: tensor([[0.8886, 0.7332, 0.9186, 0.8453]])
